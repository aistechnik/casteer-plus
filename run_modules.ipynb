# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/aistechnik/casteer-plus
# %cd casteer-plus
# !pip install -r requirements.txt
# Out:
# Cloning into 'conceptor'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 18 (delta 4), reused 17 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 1.36 MiB | 3.88 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/conceptor
# ...
# INFO: pip is looking at multiple versions of xformers to determine which version is compatible with other requirements. This could take a while.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 MB 7.8 MB/s eta 0:00:00
# ...

# %%
# !python3 -m compute_steering_vectors.py --model="sdxl-turbo" --mode="style" --concept_pos="anime" --concept_neg=None --num_denoising_steps=50 --save_dir="/content/drive/My Drive/castpl/steering_vectors"
# Out:
# 2025-12-30 05:18:45.315090: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767071925.334821     714 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767071925.340914     714 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767071925.356001     714 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python3 -m generate_casteer.py --model="sdxl-turbo" --prompt="a girl with a kitty" --seed=0 --steering_vectors="/content/drive/My Drive/castpl/steering_vectors" --num_denoising_steps=50 --save_dir="/content/drive/My Drive/castpl/generated_images"
# Out:
# '/my-drive'

# %%
# %ls
# Out:
# sd14_anime_None.pickle  steering_vectors/

# %%
# %cd /my-drive/steering_vectors
# Out:
# /my-drive/steering_vectors

# %%
# %ls
# Out:
# sd14_anime_None.pickle

# %%
# %cd /my-drive/steering_vectors
# Out:
# [Errno 2] No such file or directory: '/my-drive/steering_vectors'
# /my-drive

# %%
# %ls
# Out:
# sd14_anime_None.pickle

# %%
# !cp /content/casteer/steering_vectors -r /my-drive

# %%
# %cp /content/casteer/steering_vectors -r /my-drive
