# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/aistechnik/casteer-plus
# %cd casteer-plus
# !pip install -r requirements.txt

# %%
# !python3 -m compute_steering_vectors --model="sdxl-turbo" --mode="style" --concept_pos="anime" --concept_neg=None --num_denoising_steps=20 --save_dir="/content/drive/My Drive/castplus/steering_vectors"

# %%
# !python3 -m generate_casteer --model="sdxl-turbo" --prompt="a girl with a kitty" --seed=0 --steering_vectors="/content/drive/My Drive/castplus/steering_vectors" --num_denoising_steps=20 --save_dir="/content/drive/My Drive/castplus/generated_images"
